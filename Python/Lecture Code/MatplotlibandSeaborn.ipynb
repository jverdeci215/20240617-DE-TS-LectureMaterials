# %%
# Pandas visualizations use Matplotlib and Seaborn as a base
# We can use these libraries by themselves for visualizations

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Use np.linspace() to generate 100 points
x = np.linspace(-10, 10, 100)

# Create a sine wave
y = np.sin(x)

# Matplotlib is incredibly versatile
# We can generate any plot that we want basically
plt.plot(x,y,marker='*')
plt.show()

# %%
df = pd.read_csv("../Data/california_housing_train.csv")

x = df['median_income']
y = df['median_house_value']

# Create a scatter plot with a few more options

plt.scatter(x, y, c='teal',marker='D',edgecolors='black')
plt.show()

# %%
# Let's take a look at some categorical data

education = ["High School", "Bachelors", "Masters", "PhD"]
values = [32, 80, 19, 5]

# We will use 3 plots stacked on top of each other to visualize this
fig, axs = plt.subplots(3, 1)

axs[0].bar(education, values)
axs[1].scatter(education, values)
axs[2].plot(education, values)


# We can give our super-plot a title
plt.suptitle("Distribution of Education")
plt.show()

# %%
from random import choice

class RandomWalk:
    """A class to generate random walks."""

    def __init__(self, num_points=50_000):
        """Initialize attributes of a random walk."""
        self.num_points = num_points

        # All walks start at (0,0)
        self.x_values = [0]
        self.y_values = [0]

    def fill_walk(self):
        """Perform a random walk."""

        # Keep taking steps until desired length is reached.
        while len(self.x_values) < self.num_points:

            # Decide which direction to go and how far to go
            x_direction = choice([1, -1])
            x_distance = choice([1, 2, 3, 4])
            x_step = x_direction * x_distance

            y_direction = choice([1, -1])
            y_distance = choice([1, 2, 3, 4])
            y_step = y_direction * y_distance

            # Reject steps that go nowhere.
            if x_step == 0 and y_step == 0:
                continue

            # Calculate the new position
            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step

            self.x_values.append(x)
            self.y_values.append(y)


# Make a Random Walk
rw = RandomWalk()
rw.fill_walk()

# Plot the points in the walk.
plt.style.use('classic')
fig, ax = plt.subplots()
point_numbers = range(rw.num_points)
ax.scatter(rw.x_values, rw.y_values, c=point_numbers, cmap=plt.cm.Reds,
           edgecolors='none', s=1)

# Emphasize the first and last points
ax.scatter(0, 0, c='green', edgecolors='none', s=25)
ax.scatter(rw.x_values[-1], rw.y_values[-1], c='blue', edgecolors='none',
           s=25)

# Remove the axes
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %%
# Seaborn

# Built on top of Matplotlib
# Pandas uses seaborn by default
# A bit easier to use

import seaborn as sns

# %%
# Default Theme

sns.set_theme()

tips = sns.load_dataset('tips')

sns.relplot(
    data=tips,
    x='total_bill',
    y='tip',
    col='time',
    hue='smoker',
    style='sex',
    size='size'
)

# %%
df = pd.read_csv('../Data/pokemon.csv')

sns.pairplot(df)
