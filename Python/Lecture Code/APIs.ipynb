# %% [markdown]
# # Application Programming Interface
# - How Software talks to Software
# - Endpoints = Methods
# - We will discussion WebAPIs
#     - What do we need:
#         - API Key/Authentication
#         - URL
#             - Base
#             - Endpoint
#         - Request Header: Metdata associated with our request
#         - Parameters: configuration for API call
#         - Payload/Data: Response that we get back

# %%
# Web APIs
# Processing text = JSON
# Request Header: application/JSON, plain/text, image/jpeg (MIME Types)

import json

# Two types of JSON representations
# JSON Data run in my program = String
# JSON Data pushed through an API = Binary

employees = [
    {
        'name': 'Digs',
        'Player1': {
            'name': 'Sam',
            'position': 'libero',
            'number': 19
            },
    },
    {
        'name': 'John',
        'company': 'Skillstorm'
    }
]

out_file = '../Data/output.json'

# Will create a binary representation
with open(out_file, 'w') as f:
    json.dump(employees, f, indent=4)

# %%
# Creates a String Representation of our JSON
json_text = json.dumps(employees)
print(type(json_text))
print(type(employees))
print(json_text)
# Out:
# <class 'str'>
# <class 'list'>
# [{"name": "Digs", "Player1": {"name": "Sam", "position": "libero", "number": 19}}, {"name": "John", "company": "Skillstorm"}]

# %%
# To read JSON out of a file use .load()

with open(out_file) as f:
    data = json.load(f)

print(type(data))
print(data)
# Out:
# <class 'list'>
# [{'name': 'Digs', 'Player1': {'name': 'Sam', 'position': 'libero', 'number': 19}}, {'name': 'John', 'company': 'Skillstorm'}]

# %%
# If we have a String of JSON we can use .loads()

json_dict = json.loads(json_text)
print(type(json_dict))
print(json_dict)
# Out:
# <class 'list'>
# [{'name': 'Digs', 'Player1': {'name': 'Sam', 'position': 'libero', 'number': 19}}, {'name': 'John', 'company': 'Skillstorm'}]

# %% [markdown]
# # Web APIs
#
# ## RESTful API
# - Simple API that will send full objects
# - Majority of Web APIs are RESTful
#
# ## SOAP API
# - Simple Object Access Protocol
# - Passes parameters so that objects can be built in the applications native code
# - wsdl schema
# - Popular in heavily regulated industries - healthcare, military, government
#
# ## XML - RPC (Remote Procedure Call: Excecuting code directly on another machine)
# - Generally not public facing
# - Apache Spark uses this to facilitate communication between nodes
#
# ## Websocket
# - Full two-way communication structure
# - Push system instead of polling
# - Realtime communication
#
# # API Request
#
# ## URL
# - Base
# - Endpoint
# - `https://api.example.com/v1/endpoint`
#
# ## Methods
# - GET - Retrieval
# - POST - Update information
# - PUT - Update the existing API Resource
# - DELETE - Deletes a resource
# - requests libarary to use these methods (requests.get(),requests.post())
#
# ## Parameters
# - Configuration settings
#
# ## Body/Payload/Data
# - Actual information that we requested
#
# ## Authentication Methods
# - No authentication
# - Username/Password
# - API Key
#      - Encryption Standard
#      - Issued by the API Owner
#      - One per person
# - OAuth
#     - 2.x
#     - Typically used for App-App communication
#     - Token Refresh - Set amount of time the OAuth token will cycle

# %%
import requests
import os

# When building a URL be consistent with your slashes
base_url = 'https://api.nytimes.com'
books_api = '/svc/books/v3'
hardcover_endpoint = '/lists/current/hardcover-fiction.json'

books_url = base_url + books_api + hardcover_endpoint

api_key = os.environ['nytimes_api_key']

# Check the docs for what parameters you need
params = {'api-key': api_key}

response = requests.get(books_url, params=params)

# %%
api_key = ''
# 3 options for protecting our data
# Option 1: is creating a constants.py
from constants import api_key

# Option 2: environment variables
# os.environ['API_KEY'] = 'API KEY'
# api_key = os.environ['API_KEY']

# Option 3: .env file
from dotenv import load_dotenv

load_dotenv()

api_key = os.environ['nytimes_api_key']
print(api_key)
# Out:
# YRhHUwtMWoVGV4miyEQmZgsek3AeEmRJ

# %%
response
# Response codes:
# 200 = Success
# 400 = Client Side Error
# 500 = Server Side Error
# Out:
# <Response [200]>

# %%
data = response.json()
data['results']['books']
# Out:
# [{'rank': 1,
#   'rank_last_week': 0,
#   'weeks_on_list': 1,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '0316258873',
#   'primary_isbn13': '9780316258876',
#   'publisher': 'Little, Brown',
#   'description': 'Nantucket residents are alarmed when a home, recently sold at an exorbitant price, goes up in flames and someone goes missing.',
#   'price': '0.00',
#   'title': 'SWAN SONG',
#   'author': 'Elin Hilderbrand',
#   'contributor': 'by Elin Hilderbrand',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780316258876.jpg',
#   'book_image_width': 323,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/0316258873?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '0316258873', 'isbn13': '9780316258876'},
#    {'isbn10': '0316577855', 'isbn13': '9780316577854'},
#    {'isbn10': '0316259705', 'isbn13': '9780316259705'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/0316258873?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9780316258876?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780316258876'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FSWAN%2BSONG%2FElin%2BHilderbrand%2F9780316258876'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780316258876'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9780316258876?aff=NYT'}],
#   'book_uri': 'nyt://book/4e9c52e4-986b-5231-999d-8a2d00eb1cb0'},
#  {'rank': 2,
#   'rank_last_week': 1,
#   'weeks_on_list': 2,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '0316565075',
#   'primary_isbn13': '9780316565073',
#   'publisher': 'Little, Brown',
#   'description': 'The Big Island of Hawaii comes under threat by a volcano at the same time a secret held by the military comes to light.',
#   'price': '0.00',
#   'title': 'ERUPTION',
#   'author': 'Michael Crichton and James Patterson',
#   'contributor': 'by Michael Crichton and James Patterson',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780316565073.jpg',
#   'book_image_width': 323,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/0316565075?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '0316565075', 'isbn13': '9780316565073'},
#    {'isbn10': '0316565083', 'isbn13': '9780316565080'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/0316565075?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9780316565073?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780316565073'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FERUPTION%2FMichael%2BCrichton%2Band%2BJames%2BPatterson%2F9780316565073'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780316565073'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9780316565073?aff=NYT'}],
#   'book_uri': 'nyt://book/385356f7-39ed-5465-849f-cac99a8bf38f'},
#  {'rank': 3,
#   'rank_last_week': 3,
#   'weeks_on_list': 19,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1250178630',
#   'primary_isbn13': '9781250178633',
#   'publisher': "St. Martin's",
#   'description': 'In 1965, a nursing student follows her brother to serve during the Vietnam War and returns to a divided America.',
#   'price': '0.00',
#   'title': 'THE WOMEN',
#   'author': 'Kristin Hannah',
#   'contributor': 'by Kristin Hannah',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781250178633.jpg',
#   'book_image_width': 333,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1250178630?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1250178630', 'isbn13': '9781250178633'},
#    {'isbn10': '1250178657', 'isbn13': '9781250178657'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1250178630?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781250178633?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781250178633'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BWOMEN%2FKristin%2BHannah%2F9781250178633'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781250178633'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9781250178633?aff=NYT'}],
#   'book_uri': 'nyt://book/9ce735af-71cf-5ff3-a367-43ee07e3fdd7'},
#  {'rank': 4,
#   'rank_last_week': 2,
#   'weeks_on_list': 3,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '0385545991',
#   'primary_isbn13': '9780385545990',
#   'publisher': 'Doubleday',
#   'description': 'The third book in the Camino series. The last living inhabitant of a deserted island gets in the way of a resort developer.',
#   'price': '0.00',
#   'title': 'CAMINO GHOSTS',
#   'author': 'John Grisham',
#   'contributor': 'by John Grisham',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780385545990.jpg',
#   'book_image_width': 329,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/0385545991?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '0385545991', 'isbn13': '9780385545990'},
#    {'isbn10': '0385546009', 'isbn13': '9780385546003'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/0385545991?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9780385545990?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780385545990'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FCAMINO%2BGHOSTS%2FJohn%2BGrisham%2F9780385545990'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780385545990'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9780385545990?aff=NYT'}],
#   'book_uri': 'nyt://book/d5a27515-6af1-5044-8c99-ff484292947a'},
#  {'rank': 5,
#   'rank_last_week': 4,
#   'weeks_on_list': 4,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1668037718',
#   'primary_isbn13': '9781668037713',
#   'publisher': 'Scribner',
#   'description': 'A dozen short stories that explore darkness in literal and metaphorical forms.',
#   'price': '0.00',
#   'title': 'YOU LIKE IT DARKER',
#   'author': 'Stephen King',
#   'contributor': 'by Stephen King',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781668037713.jpg',
#   'book_image_width': 329,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1668037718?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1668037718', 'isbn13': '9781668037713'},
#    {'isbn10': '1668037734', 'isbn13': '9781668037737'},
#    {'isbn10': '1797174622', 'isbn13': '9781797174624'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1668037718?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781668037713?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781668037713'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FYOU%2BLIKE%2BIT%2BDARKER%2FStephen%2BKing%2F9781668037713'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781668037713'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9781668037713?aff=NYT'}],
#   'book_uri': 'nyt://book/84fc5c9e-1607-56f8-afcd-0ee37bfc8237'},
#  {'rank': 6,
#   'rank_last_week': 7,
#   'weeks_on_list': 8,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '0593441281',
#   'primary_isbn13': '9780593441282',
#   'publisher': 'Berkley',
#   'description': 'After their exes run off together, Daphne and Miles form a friendship and concoct a plan involving misleading photos.',
#   'price': '0.00',
#   'title': 'FUNNY STORY',
#   'author': 'Emily Henry',
#   'contributor': 'by Emily Henry',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780593441282.jpg',
#   'book_image_width': 331,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/0593441281?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '0593441281', 'isbn13': '9780593441282'},
#    {'isbn10': '0593441222', 'isbn13': '9780593441220'},
#    {'isbn10': '0593826299', 'isbn13': '9780593826294'},
#    {'isbn10': '0593826280', 'isbn13': '9780593826287'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/0593441281?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9780593441282?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780593441282'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FFUNNY%2BSTORY%2FEmily%2BHenry%2F9780593441282'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780593441282'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9780593441282?aff=NYT'}],
#   'book_uri': 'nyt://book/e4f437a2-9715-56c0-90ae-cb569773dcce'},
#  {'rank': 7,
#   'rank_last_week': 8,
#   'weeks_on_list': 58,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1649374046',
#   'primary_isbn13': '9781649374042',
#   'publisher': 'Red Tower',
#   'description': 'Violet Sorrengail is urged by the commanding general, who also is her mother, to become a candidate for the elite dragon riders.',
#   'price': '0.00',
#   'title': 'FOURTH WING',
#   'author': 'Rebecca Yarros',
#   'contributor': 'by Rebecca Yarros',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781649374042.jpg',
#   'book_image_width': 309,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1649374046?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1649374046', 'isbn13': '9781649374042'},
#    {'isbn10': '1649374089', 'isbn13': '9781649374080'},
#    {'isbn10': '1705085059', 'isbn13': '9781705085059'},
#    {'isbn10': '1705085032', 'isbn13': '9781705085035'},
#    {'isbn10': '1649376162', 'isbn13': '9781649376169'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1649374046?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781649374042?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781649374042'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FFOURTH%2BWING%2FRebecca%2BYarros%2F9781649374042'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781649374042'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9781649374042?aff=NYT'}],
#   'book_uri': 'nyt://book/106c2cf0-7d20-51b1-bad4-91c3ebcd131a'},
#  {'rank': 8,
#   'rank_last_week': 9,
#   'weeks_on_list': 32,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1649374178',
#   'primary_isbn13': '9781649374172',
#   'publisher': 'Red Tower',
#   'description': 'The second book in the Empyrean series. Violet Sorrengail’s next round of training might require her to betray the man she loves.',
#   'price': '0.00',
#   'title': 'IRON FLAME',
#   'author': 'Rebecca Yarros',
#   'contributor': 'by Rebecca Yarros',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781649374172.jpg',
#   'book_image_width': 309,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1649374178?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1649374178', 'isbn13': '9781649374172'},
#    {'isbn10': '1705085083', 'isbn13': '9781705085080'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1649374178?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781649374172?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781649374172'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FIRON%2BFLAME%2FRebecca%2BYarros%2F9781649374172'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781649374172'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9781649374172?aff=NYT'}],
#   'book_uri': 'nyt://book/d3c570c9-3c3a-5c8b-a740-85ea5e92bfc9'},
#  {'rank': 9,
#   'rank_last_week': 6,
#   'weeks_on_list': 2,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1649374070',
#   'primary_isbn13': '9781649374073',
#   'publisher': 'Red Tower',
#   'description': 'A thief breaks the Monster Treaty that was created in the aftermath of the destruction of New York City years ago.',
#   'price': '0.00',
#   'title': 'THE WREN IN THE HOLLY LIBRARY',
#   'author': 'K.A. Linde',
#   'contributor': 'by K.A. Linde',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781649374073.jpg',
#   'book_image_width': 309,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1649374070?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1649374070', 'isbn13': '9781649374073'},
#    {'isbn10': '1649377118', 'isbn13': '9781649377111'},
#    {'isbn10': '1649374224', 'isbn13': '9781649374226'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1649374070?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781649374073?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781649374073'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BWREN%2BIN%2BTHE%2BHOLLY%2BLIBRARY%2FK.A.%2BLinde%2F9781649374073'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781649374073'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9781649374073?aff=NYT'}],
#   'book_uri': 'nyt://book/ff624f83-7711-5267-a867-14cc8c813dec'},
#  {'rank': 10,
#   'rank_last_week': 0,
#   'weeks_on_list': 1,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1250283809',
#   'primary_isbn13': '9781250283801',
#   'publisher': "St. Martin's",
#   'description': 'An aspiring screenwriter hopes to convince a famous but jaded screenwriter that love stories matter.',
#   'price': '0.00',
#   'title': 'THE ROM-COMMERS',
#   'author': 'Katherine Center',
#   'contributor': 'by Katherine Center',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781250283801.jpg',
#   'book_image_width': 361,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1250283809?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1250283809', 'isbn13': '9781250283801'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1250283809?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781250283801?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781250283801'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BROM-COMMERS%2FKatherine%2BCenter%2F9781250283801'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781250283801'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9781250283801?aff=NYT'}],
#   'book_uri': 'nyt://book/7cb02254-7b58-5375-81b2-e5e125399e70'},
#  {'rank': 11,
#   'rank_last_week': 11,
#   'weeks_on_list': 9,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '0385550367',
#   'primary_isbn13': '9780385550369',
#   'publisher': 'Doubleday',
#   'description': "A reimagining of “Adventures of Huckleberry Finn” shines a different light on Mark Twain's classic, revealing new facets of the character of Jim.",
#   'price': '0.00',
#   'title': 'JAMES',
#   'author': 'Percival Everett',
#   'contributor': 'by Percival Everett',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780385550369.jpg',
#   'book_image_width': 333,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/0385550367?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '0385550367', 'isbn13': '9780385550369'},
#    {'isbn10': '0385550375', 'isbn13': '9780385550376'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/0385550367?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9780385550369?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780385550369'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FJAMES%2FPercival%2BEverett%2F9780385550369'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780385550369'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9780385550369?aff=NYT'}],
#   'book_uri': 'nyt://book/5788b098-426a-5f2c-a318-475692df69ee'},
#  {'rank': 12,
#   'rank_last_week': 5,
#   'weeks_on_list': 2,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1250343151',
#   'primary_isbn13': '9781250343154',
#   'publisher': 'Bramble',
#   'description': 'The second book in the Crowns of Nyaxia series. Oraya faces a difficult choice between love and power.',
#   'price': '0.00',
#   'title': 'THE ASHES & THE STAR-CURSED KING',
#   'author': 'Carissa Broadbent',
#   'contributor': 'by Carissa Broadbent',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781250343154.jpg',
#   'book_image_width': 323,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1250343151?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1250343151', 'isbn13': '9781250343154'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1250343151?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781250343154?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781250343154'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FTHE%2BASHES%2B%2526%2BTHE%2BSTAR-CURSED%2BKING%2FCarissa%2BBroadbent%2F9781250343154'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781250343154'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9781250343154?aff=NYT'}],
#   'book_uri': 'nyt://book/1a1330fb-d34e-52b6-b7a0-81f2e8490f2d'},
#  {'rank': 13,
#   'rank_last_week': 0,
#   'weeks_on_list': 1,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '0063070014',
#   'primary_isbn13': '9780063070011',
#   'publisher': 'Morrow',
#   'description': 'A Hollywood reboot of an art-house horror flick brings up decades-old, on-set tragedies for its sole surviving cast member.',
#   'price': '0.00',
#   'title': 'HORROR MOVIE',
#   'author': 'Paul Tremblay',
#   'contributor': 'by Paul Tremblay',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780063070011.jpg',
#   'book_image_width': 331,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/0063070014?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '0063070014', 'isbn13': '9780063070011'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/0063070014?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9780063070011?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780063070011'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FHORROR%2BMOVIE%2FPaul%2BTremblay%2F9780063070011'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780063070011'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9780063070011?aff=NYT'}],
#   'book_uri': 'nyt://book/d2aa511f-1124-53d9-acc9-dd0b521b9b25'},
#  {'rank': 14,
#   'rank_last_week': 0,
#   'weeks_on_list': 8,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '1538765020',
#   'primary_isbn13': '9781538765029',
#   'publisher': 'Grand Central',
#   'description': 'Lawyers from different backgrounds represent a Black man charged with killing a wealthy white couple in Virginia in 1968.',
#   'price': '0.00',
#   'title': 'A CALAMITY OF SOULS',
#   'author': 'David Baldacci',
#   'contributor': 'by David Baldacci',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9781538765029.jpg',
#   'book_image_width': 331,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/1538765020?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '1538765020', 'isbn13': '9781538765029'},
#    {'isbn10': '1538768356', 'isbn13': '9781538768358'},
#    {'isbn10': '1538766477', 'isbn13': '9781538766477'},
#    {'isbn10': '1538765055', 'isbn13': '9781538765050'},
#    {'isbn10': '166863709X', 'isbn13': '9781668637098'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/1538765020?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9781538765029?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9781538765029'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FA%2BCALAMITY%2BOF%2BSOULS%2FDavid%2BBaldacci%2F9781538765029'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9781538765029'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9781538765029?aff=NYT'}],
#   'book_uri': 'nyt://book/077c6e94-e5e8-51aa-890a-f8d9ce4f926d'},
#  {'rank': 15,
#   'rank_last_week': 0,
#   'weeks_on_list': 1,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '0802163076',
#   'primary_isbn13': '9780802163073',
#   'publisher': 'Atlantic Monthly',
#   'description': 'The 24th book in the Dave Robicheaux series. Robicheaux and his partner Clete Purcel go after smugglers of a new drug.',
#   'price': '0.00',
#   'title': 'CLETE',
#   'author': 'James Lee Burke',
#   'contributor': 'by James Lee Burke',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780802163073.jpg',
#   'book_image_width': 331,
#   'book_image_height': 500,
#   'amazon_product_url': 'https://www.amazon.com/dp/0802163076?tag=thenewyorktim-20',
#   'age_group': '',
#   'book_review_link': '',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
#   'isbns': [{'isbn10': '0802163076', 'isbn13': '9780802163073'}],
#   'buy_links': [{'name': 'Amazon',
#     'url': 'https://www.amazon.com/dp/0802163076?tag=thenewyorktim-20'},
#    {'name': 'Apple Books',
#     'url': 'https://goto.applebooks.apple/9780802163073?at=10lIEQ'},
#    {'name': 'Barnes and Noble',
#     'url': 'https://www.anrdoezrs.net/click-7990613-11819508?url=https%3A%2F%2Fwww.barnesandnoble.com%2Fw%2F%3Fean%3D9780802163073'},
#    {'name': 'Books-A-Million',
#     'url': 'https://www.anrdoezrs.net/click-7990613-35140?url=https%3A%2F%2Fwww.booksamillion.com%2Fp%2FCLETE%2FJames%2BLee%2BBurke%2F9780802163073'},
#    {'name': 'Bookshop', 'url': 'https://bookshop.org/a/3546/9780802163073'},
#    {'name': 'IndieBound',
#     'url': 'https://www.indiebound.org/book/9780802163073?aff=NYT'}],
#   'book_uri': 'nyt://book/29dee63c-548c-5515-8cfe-ee5e41e025f8'}]

# %%
book_titles = [books['title'] for books in data['results']['books']]
book_titles
# Out:
# ['SWAN SONG',
#  'ERUPTION',
#  'THE WOMEN',
#  'CAMINO GHOSTS',
#  'YOU LIKE IT DARKER',
#  'FUNNY STORY',
#  'FOURTH WING',
#  'IRON FLAME',
#  'THE WREN IN THE HOLLY LIBRARY',
#  'THE ROM-COMMERS',
#  'JAMES',
#  'THE ASHES & THE STAR-CURSED KING',
#  'HORROR MOVIE',
#  'A CALAMITY OF SOULS',
#  'CLETE']

# %%
import pandas as pd

books = data['results']['books']
df = pd.json_normalize(books)
df.head()
# Out:
#    rank  rank_last_week  weeks_on_list  asterisk  dagger primary_isbn10  \
# 0     1               0              1         0       0     0316258873
# 1     2               1              2         0       0     0316565075
# 2     3               3             19         0       0     1250178630
# 3     4               2              3         0       0     0385545991
# 4     5               4              4         0       0     1668037718
#
#   primary_isbn13      publisher  \
# 0  9780316258876  Little, Brown
# 1  9780316565073  Little, Brown
# 2  9781250178633   St. Martin's
# 3  9780385545990      Doubleday
# 4  9781668037713       Scribner
#
#                                          description price  ...  \
# 0  Nantucket residents are alarmed when a home, r...  0.00  ...
# 1  The Big Island of Hawaii comes under threat by...  0.00  ...
# 2  In 1965, a nursing student follows her brother...  0.00  ...
# 3  The third book in the Camino series. The last ...  0.00  ...
# 4  A dozen short stories that explore darkness in...  0.00  ...
#
#   book_image_height                                 amazon_product_url  \
# 0               500  https://www.amazon.com/dp/0316258873?tag=thene...
# 1               500  https://www.amazon.com/dp/0316565075?tag=thene...
# 2               500  https://www.amazon.com/dp/1250178630?tag=thene...
# 3               500  https://www.amazon.com/dp/0385545991?tag=thene...
# 4               500  https://www.amazon.com/dp/1668037718?tag=thene...
#
#   age_group book_review_link first_chapter_link  sunday_review_link  \
# 0
# 1
# 2
# 3
# 4
#
#    article_chapter_link                                              isbns  \
# 0                        [{'isbn10': '0316258873', 'isbn13': '978031625...
# 1                        [{'isbn10': '0316565075', 'isbn13': '978031656...
# 2                        [{'isbn10': '1250178630', 'isbn13': '978125017...
# 3                        [{'isbn10': '0385545991', 'isbn13': '978038554...
# 4                        [{'isbn10': '1668037718', 'isbn13': '978166803...
#
#                                            buy_links  \
# 0  [{'name': 'Amazon', 'url': 'https://www.amazon...
# 1  [{'name': 'Amazon', 'url': 'https://www.amazon...
# 2  [{'name': 'Amazon', 'url': 'https://www.amazon...
# 3  [{'name': 'Amazon', 'url': 'https://www.amazon...
# 4  [{'name': 'Amazon', 'url': 'https://www.amazon...
#
#                                           book_uri
# 0  nyt://book/4e9c52e4-986b-5231-999d-8a2d00eb1cb0
# 1  nyt://book/385356f7-39ed-5465-849f-cac99a8bf38f
# 2  nyt://book/9ce735af-71cf-5ff3-a367-43ee07e3fdd7
# 3  nyt://book/d5a27515-6af1-5044-8c99-ff484292947a
# 4  nyt://book/84fc5c9e-1607-56f8-afcd-0ee37bfc8237
#
# [5 rows x 26 columns]

# %%
# We can check the metadata details of our response
response.headers
# Out:
# {'Date': 'Fri, 21 Jun 2024 14:23:01 GMT', 'Content-Type': 'application/json; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Server': 'Apache/2.4.38 (Debian)', 'X-Powered-By': 'PHP/7.4.13', 'Via': '1.1 google, 1.1 varnish', 'Content-Encoding': 'gzip', 'Accept-Ranges': 'bytes', 'Age': '1032', 'X-Served-By': 'cache-iad-kiad7000099-IAD', 'X-Cache': 'HIT', 'X-Cache-Hits': '1', 'X-Timer': 'S1718979781.270597,VS0,VE1', 'Vary': 'Accept-Encoding', 'x-nyt-mktg-group': 'group1', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Headers': 'Accept, Content-Type, X-Forwarded-For, X-Prototype-Version, X-Requested-With', 'Access-Control-Expose-Headers': 'Content-Length, X-JSON', 'Access-Control-Allow-Methods': 'GET, OPTIONS', 'Strict-Transport-Security': 'max-age=63072000; preload; includeSubdomains'}

# %%
response.encoding
# Out:
# 'UTF-8'

# %%
response.status_code
# Out:
# 200
